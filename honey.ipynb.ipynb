# %% [markdown]
# Bee Population Health in the U.S. — A State-by-State, Year-by-Year Story
#
# This notebook uses the provided `honey.csv` dataset to explore the health of the U.S. bee population across states and years.

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
honey = pd.read_csv('data\data/honey.csv')
honey.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\windo\AppData\Local\Temp\ipykernel_2084\2190464320.py:2: SyntaxWarning: invalid escape sequence '\d'
#   honey = pd.read_csv('data\data/honey.csv')
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
hn = honey[honey['state']=='AZ']
print(len(hn))
hn
# Out:
# 15
#     state   numcol  yieldpercol  totalprod     stocks  priceperlb  prodvalue  \
# 1      AZ  55000.0           60  3300000.0  1485000.0        0.64  2112000.0
# 44     AZ  52000.0           62  3224000.0  1548000.0        0.62  1999000.0
# 87     AZ  40000.0           59  2360000.0  1322000.0        0.73  1723000.0
# 130    AZ  43000.0           59  2537000.0  1142000.0        0.72  1827000.0
# 174    AZ  38000.0           63  2394000.0  1197000.0        1.08  2586000.0
# 218    AZ  35000.0           72  2520000.0   983000.0        1.34  3377000.0
# 262    AZ  32000.0           55  1760000.0   774000.0        1.11  1954000.0
# 303    AZ  36000.0           50  1800000.0   720000.0        1.04  1872000.0
# 344    AZ  30000.0           65  1950000.0   839000.0        0.91  1775000.0
# 385    AZ  30000.0           64  1920000.0   902000.0        1.26  2419000.0
# 426    AZ  25000.0           64  1600000.0   336000.0        1.26  2016000.0
# ...

# %%
sns.relplot(x="prodvalue", y="state", data=honey, height=15, aspect=.5);

# %%
sns.relplot(x="prodvalue", y="state", hue="year", palette="YlOrBr", data=honey, height=15, aspect=.5);

# %%
sns.relplot(x="priceperlb", y="state", size="year", data=honey, height=15, aspect=.5);

# %%
sns.relplot(x="year", y="prodvalue", kind="line", data=hn);

# %%
sns.relplot(
    data=honey, 
    x="numcol", y="priceperlb",
    col="year", 
    col_wrap=2,
    kind="line"
)

# %%
fig, ax = plt.subplots(figsize=(12,6))
lineplot = sns.lineplot(x=honey['year'], y=honey['numcol'], data=honey, 
                        label = 'Number of bee colonies', legend=False)
sns.despine()
plt.ylabel('# colonies')
plt.title('Honey Production Year over Year');

ax2 = ax.twinx()
lineplot2 = sns.lineplot(x=honey['year'], y=honey['yieldpercol'], ax=ax2, color="r", 
                         label ='Yield per colony', legend=False) 
sns.despine(right=False)
plt.ylabel('colony yield')
ax.figure.legend();
